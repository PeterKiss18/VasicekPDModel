# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from src.ML_estimation import calculate_my_likelihood
from src.sucess_probability import p_g

# %%
d_g = 2481
n_g = 66871

# %%
# Plot of the likelihood function in w_g and gamma_g
x_num_points = 100
y_num_points = 100
w_g = np.linspace(0, 0.4, x_num_points)
gamma_g = np.linspace(-2, 2, y_num_points)
W, G = np.meshgrid(w_g, gamma_g)
L = np.zeros((x_num_points, y_num_points))
for i in range(x_num_points):
    for j in range(y_num_points):
        L[i, j] = calculate_my_likelihood(d_g, n_g, p_g, norm.pdf, w_g[i], gamma_g[j])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W, G, L, cmap='viridis')
ax.set_xlabel('w_g')
ax.set_ylabel('gamma_g')
ax.set_zlabel('Likelihood')
plt.show()

# %%
# Plot of the likelihood function in w_g and gamma_g
x_num_points = 20
y_num_points = 20
w_g = np.linspace(0, 0.2, x_num_points)
gamma_g = np.linspace(-3, 2, y_num_points)
W, G = np.meshgrid(w_g, gamma_g)
L = np.zeros((x_num_points, y_num_points))
for i in range(x_num_points):
    for j in range(y_num_points):
        L[i, j] = np.log(calculate_my_likelihood(d_g, n_g, p_g, norm.pdf, w_g[i], gamma_g[j]))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W, G, L, cmap='viridis')
ax.set_xlabel('w_g')
ax.set_ylabel('gamma_g')
ax.set_zlabel('Likelihood')
plt.show()
# Out:
# C:\Users\kissp\AppData\Local\Temp\ipykernel_13720\4133256387.py:10: RuntimeWarning: divide by zero encountered in log
#   L[i, j] = np.log(calculate_my_likelihood(d_g, n_g, p_g, norm.pdf, w_g[i], gamma_g[j]))

# %%
# Plot of the likelihood function in w_g and gamma_g
x_num_points = 20
y_num_points = 20
w_g = np.linspace(0, 0.2, x_num_points)
gamma_g = np.linspace(-3, 2, y_num_points)
W, G = np.meshgrid(w_g, gamma_g)
L = np.zeros((x_num_points, y_num_points))
for i in range(x_num_points):
    for j in range(y_num_points):
        L[i, j] = calculate_my_likelihood(d_g, n_g, p_g, norm.pdf, w_g[i], gamma_g[j])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W, G, L, cmap='viridis')
ax.set_xlabel('w_g')
ax.set_ylabel('gamma_g')
ax.set_zlabel('Likelihood')
plt.show()

# %%
# Plot of the likelihood function in w_g and gamma_g
x_num_points = 20
y_num_points = 20
w_g = np.linspace(0, 0.10, x_num_points)
gamma_g = np.linspace(-2, 0, y_num_points)
W, G = np.meshgrid(w_g, gamma_g)
L = np.zeros((x_num_points, y_num_points))
for i in range(x_num_points):
    for j in range(y_num_points):
        L[i, j] = calculate_my_likelihood(d_g, n_g, p_g, norm.pdf, w_g[i], gamma_g[j])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W, G, L, cmap='viridis')
ax.set_xlabel('w_g')
ax.set_ylabel('gamma_g')
ax.set_zlabel('Likelihood')
plt.show()

# %%
# Plot of the likelihood function in w_g and gamma_g
x_num_points = 20
y_num_points = 20
w_g = np.linspace(0, 0.02, x_num_points)
gamma_g = np.linspace(-2.2, -0.2, y_num_points)
W, G = np.meshgrid(w_g, gamma_g)
L = np.zeros((x_num_points, y_num_points))
for i in range(x_num_points):
    for j in range(y_num_points):
        L[i, j] = calculate_my_likelihood(d_g, n_g, p_g, norm.pdf, w_g[i], gamma_g[j])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W, G, L, cmap='viridis')
ax.set_xlabel('w_g')
ax.set_ylabel('gamma_g')
ax.set_zlabel('Likelihood')
plt.show()

# %%
# Plot of the likelihood function in a and b
x_num_points = 30
y_num_points = 100
a = np.linspace(-3, 3, x_num_points)
b = np.linspace(-5, 5, y_num_points)
A, B = np.meshgrid(a, b)
L = np.zeros((y_num_points, x_num_points))

modified_p_g = lambda x, a, b: norm.cdf(a + b * x)
for i in range(x_num_points):
    for j in range(y_num_points):
        L[j, i] = calculate_my_likelihood(d_g, n_g, modified_p_g, norm.pdf, a[i], b[j])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(A, B, L, cmap='viridis')
ax.set_xlabel('a')
ax.set_ylabel('b')
ax.set_zlabel('Likelihood')
plt.show()
# Out:
# C:\Users\kissp\PycharmProjects\VasicekPDModell\src\ML_estimation.py:26: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   result, _ = quad(integrand, -5, 5)

# %%
# Plot of the likelihood function in a and b
x_num_points = 70
y_num_points = 80
a = np.linspace(-2.5, -1, x_num_points)
b = np.linspace(-1, 1, y_num_points)
A, B = np.meshgrid(a, b)
L = np.zeros((y_num_points, x_num_points))

modified_p_g = lambda x, a, b: norm.cdf(a + b * x)
for i in range(x_num_points):
    for j in range(y_num_points):
        L[j, i] = calculate_my_likelihood(d_g, n_g, modified_p_g, norm.pdf, a[i], b[j])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(A, B, L, cmap='viridis')
ax.set_xlabel('a')
ax.set_ylabel('b')
ax.set_zlabel('Likelihood')
plt.show()

# %%
# Plot of the likelihood function in a and b
x_num_points = 30
y_num_points = 40
a = np.linspace(-3, 0, x_num_points)
b = np.linspace(-2, 2, y_num_points)
A, B = np.meshgrid(a, b)
L = np.zeros((y_num_points, x_num_points))

modified_p_g = lambda x, a, b: norm.cdf(a + b * x)
for i in range(x_num_points):
    for j in range(y_num_points):
        L[j, i] = np.log(calculate_my_likelihood(d_g, n_g, modified_p_g, norm.pdf, a[i], b[j]))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(A, B, L, cmap='viridis')
ax.set_xlabel('a')
ax.set_ylabel('b')
ax.set_zlabel('Log-Likelihood')
plt.show()
# Out:
# C:\Users\kissp\AppData\Local\Temp\ipykernel_19192\750996930.py:12: RuntimeWarning: divide by zero encountered in log
#   L[j, i] = np.log(calculate_my_likelihood(d_g, n_g, modified_p_g, norm.pdf, a[i], b[j]))

# %%
# Plot of the likelihood function in a and b
x_num_points = 30
y_num_points = 40
a = np.linspace(-3, 0, x_num_points)
b = np.linspace(-2, 2, y_num_points)
A, B = np.meshgrid(a, b)
L = np.zeros((y_num_points, x_num_points))

modified_p_g = lambda x, a, b: norm.cdf(a + b * x)
for i in range(x_num_points):
    for j in range(y_num_points):
        L[j, i] = np.log(calculate_my_likelihood(d_g, n_g, modified_p_g, norm.pdf, a[i], b[j]))

plt.contour(A, B, L, levels=20, cmap='viridis')
plt.xlabel('a')
plt.ylabel('b')
plt.title('Log-Likelihood Contours')
plt.colorbar(label='Log-Likelihood')
plt.show()
# Out:
# C:\Users\kissp\AppData\Local\Temp\ipykernel_7164\1554959139.py:12: RuntimeWarning: divide by zero encountered in log
#   L[j, i] = np.log(calculate_my_likelihood(d_g, n_g, modified_p_g, norm.pdf, a[i], b[j]))
# C:\Users\kissp\PycharmProjects\VasicekPDModell\src\ML_estimation.py:28: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   result, _ = quad(integrand, -3, 3)

# %%
# Plot of the likelihood function in a and b
x_num_points = 70
y_num_points = 80
a = np.linspace(-2.5, -1, x_num_points)
b = np.linspace(-1, 1, y_num_points)
A, B = np.meshgrid(a, b)
L = np.zeros((y_num_points, x_num_points))

modified_p_g = lambda x, a, b: norm.cdf(a + b * x)
for i in range(x_num_points):
    for j in range(y_num_points):
        L[j, i] = calculate_my_likelihood(d_g, n_g, modified_p_g, norm.pdf, a[i], b[j])

plt.contour(A, B, L, levels=20, cmap='viridis')
plt.xlabel('a')
plt.ylabel('b')
plt.title('Likelihood Contours')
plt.colorbar(label='Likelihood')
plt.show()

# %%
# Plot of the likelihood function in w_g and gamma_g
x_num_points = 20
y_num_points = 20
w_g = np.linspace(0, 0.2, x_num_points)
gamma_g = np.linspace(-3, 2, y_num_points)
W, G = np.meshgrid(w_g, gamma_g)
L = np.zeros((y_num_points, x_num_points))

for i in range(x_num_points):
    for j in range(y_num_points):
        L[j, i] = calculate_my_likelihood(d_g, n_g, p_g, norm.pdf, w_g[i], gamma_g[j])

plt.contour(W, G, L, levels=20, cmap='viridis')
plt.xlabel('w_g')
plt.ylabel('gamma_g')
plt.title('Likelihood Contours')
plt.colorbar(label='Likelihood')
plt.show()

# %% [markdown]
# # Plot of the likelihood function on SP data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from src.MM_estimation import estimate_w_factor_loading, calc_variance_of_default_rate
from src.ML_estimation import calculate_my_likelihood_arr
from src.ML_estimation import ml_estimation_linear_with_w_and_g
from src.ML_estimation import parameter_estimation
from src.variable_change import a_calc_func, b_calc_func, w_calc_func, gamma_calc_func
from src.ML_estimation import calculate_variable_changed_likelihood_arr
from src.sucess_probability import p_g
from scipy.optimize import minimize

# %%
# Load the data
grades_data = pd.read_csv('data/grades_hist_pd.csv', sep=';', index_col=0)

for col_name in grades_data.columns:
    grades_data[col_name] = grades_data[col_name] / 100
    
grades_cols = grades_data.columns

n_g_assumption = 3000

for col_name in grades_cols:
    grades_data[str(col_name) + " defaults"] = (n_g_assumption * grades_data[col_name])
    
num_of_rows = grades_data.shape[0]
n_g_over_time = np.array([n_g_assumption] * grades_data.shape[0])

# Choose last four columns and calculate the sum of defaults
d_g = grades_data.iloc[:, -5:].sum(axis=0).tolist()
d_g = np.array([int(round(x)) for x in d_g])
n_g = np.array([n_g_assumption * grades_data.shape[0]] * len(d_g))

# %%
grades_data.iloc[25:28]
# Out:
#       AAA      AA       A     BBB      BB       B   CCC/C  AAA defaults  \
# Year
# 2006  0.0  0.0000  0.0000  0.0000  0.0030  0.0082  0.1333           0.0
# 2007  0.0  0.0000  0.0000  0.0000  0.0020  0.0025  0.1524           0.0
# 2008  0.0  0.0038  0.0039  0.0049  0.0081  0.0411  0.2727           0.0
#
#       AA defaults  A defaults  BBB defaults  BB defaults  B defaults  \
# Year
# 2006          0.0         0.0           0.0          9.0        24.6
# 2007          0.0         0.0           0.0          6.0         7.5
# 2008         11.4        11.7          14.7         24.3       123.3
#
#       CCC/C defaults
# Year
# 2006           399.9
# 2007           457.2
# 2008           818.1

# %%
MM_params = {}
for grade in ["A", "BBB", "BB", "B", "CCC/C"]:
    MM_params[grade] = estimate_w_factor_loading(grades_data[grade], n_g_over_time, initial_guess=0.45)
    print(f"Estimated parameters with method of moments for grade {grade}:", MM_params[grade][0], norm.ppf(MM_params[grade][1]))
    
MM_gammas = [norm.ppf(MM_params[grade][1]) for grade in ["A", "BBB", "BB", "B", "CCC/C"]]
MM_ws = [MM_params[grade][0] for grade in ["A", "BBB", "BB", "B", "CCC/C"]]
# Out:
# Estimated parameters with method of moments for grade A: 0.4499803380652506 -3.274097580352716
# Estimated parameters with method of moments for grade BBB: 0.3133851305078121 -2.8865426119490847
# Estimated parameters with method of moments for grade BB: 0.34959246714062564 -2.3842278912651227
# Estimated parameters with method of moments for grade B: 0.3288445137084037 -1.728911139866942
# Estimated parameters with method of moments for grade CCC/C: 0.36077988602478867 -0.6770330266259245

# %%
# calculate parameters in a and b
a_mm = []
b_mm = []
for grade in ["A", "BBB", "BB", "B", "CCC/C"]:
    a_mm.append(a_calc_func(MM_params[grade][0], norm.ppf(MM_params[grade][1])))
    b_mm.append(b_calc_func(MM_params[grade][0], norm.ppf(MM_params[grade][1])))
    print(f"Estimated a and b parameters with method of moments for grade {grade}:", a_mm[-1], b_mm[-1])
# Out:
# Estimated a and b parameters with method of moments for grade A: -0.5038756526205921 -3.666244756686461
# Estimated a and b parameters with method of moments for grade BBB: -0.33000896380650985 -3.039662203529174
# Estimated a and b parameters with method of moments for grade BB: -0.3731366963251691 -2.544800023608999
# Estimated a and b parameters with method of moments for grade B: -0.3482105655410494 -1.830728811602197
# Estimated a and b parameters with method of moments for grade CCC/C: -0.386832683308205 -0.7259232360863574

# %%
# Choose 2 grades: B and BB
d_g2 = [d_g[2], d_g[3]]
n_g2 = [n_g[2], n_g[3]]

# Make a 2D plot conjecturing the log likelihood function in a and b2 if b1 is fixed
b1_fixed = b_calc_func(MM_params["B"][0], norm.ppf(MM_params["B"][1]))

a_array = np.linspace(-2, 0, 21)
b2_array = np.linspace(-3, 0, 31)

a_l, b2_l = np.meshgrid(a_array, b2_array)

z_values_a_b2 = np.zeros((len(b2_array), len(a_array)))

for i, x in enumerate(a_array):
    for j, y in enumerate(b2_array):
        z_values_a_b2[j, i] = -np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([x, x]), np.array([b1_fixed,y])))
    
plt.contourf(a_l, b2_l, z_values_a_b2, 20, cmap='RdGy')
plt.colorbar()
plt.xlabel("a")
plt.ylabel("b2")
plt.title("Log likelihood for different a values")
plt.show()
# Out:
# C:\Users\kissp\AppData\Local\Temp\ipykernel_27040\1038192937.py:17: RuntimeWarning: divide by zero encountered in log
#   z_values_a_b2[j, i] = -np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([x, x]), np.array([b1_fixed,y])))

# %%
# Find the minimum value of the log likelihood function
min_a_b2_value = np.min(z_values_a_b2)
min_a_b2_index = np.where(z_values_a_b2 == min_a_b2_value)
a_min_param = a_array[min_a_b2_index[1][0]]
b2_min_param = b2_array[min_a_b2_index[0][0]]
a_min_param, b2_min_param, min_a_b2_value
# Out:
# (-0.5, -1.2, 16.369564775645813)

# %%
w_calc_func(a_min_param, b1_fixed), gamma_calc_func(a_min_param, b1_fixed), w_calc_func(a_min_param, b2_min_param), gamma_calc_func(a_min_param, b2_min_param)
# Out:
# (0.4472135954999579,
#  -1.6374536284439671,
#  0.4472135954999579,
#  -1.073312629199899)

# %%
-np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([a_min_param, a_min_param]), np.array([b1_fixed, b2_min_param])))
# Out:
# 16.369564775645813

# %%
a_mm[2], b_mm[2], a_mm[3], b_mm[3]
# Out:
# (-0.3731366963251691,
#  -2.544800023608999,
#  -0.3482105655410494,
#  -1.830728811602197)

# %%
-np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([a_mm[2], a_mm[2]]), np.array([b_mm[2], b_mm[3]])))
# Out:
# 23.596395084022955

# %%
# Choose 2 grades: B and BB
d_g2 = [d_g[2], d_g[3]]
n_g2 = [n_g[2], n_g[3]]

# Make a 2D plot conjecturing the log likelihood function in a and b2 if b1 is fixed
b1_fixed = b_calc_func(MM_params["B"][0], norm.ppf(MM_params["B"][1]))

a_array2 = np.linspace(-3, 0, 61)
b2_array2 = np.linspace(-2, -0.5, 51)

a_l2, b2_l2 = np.meshgrid(a_array2, b2_array2)

z2_values_a_b2 = np.zeros((len(b2_array2), len(a_array2)))

for i, x in enumerate(a_array2):
    for j, y in enumerate(b2_array2):
        z2_values_a_b2[j, i] = -np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([x, x]), np.array([b1_fixed,y])))
    
plt.contourf(a_l2, b2_l2, z2_values_a_b2, 20, cmap='RdGy')
plt.colorbar()
plt.xlabel("a")
plt.ylabel("b2")
plt.title("Log likelihood for different a values")
plt.show()
# Out:
# C:\Users\kissp\AppData\Local\Temp\ipykernel_27040\3233533877.py:17: RuntimeWarning: divide by zero encountered in log
#   z2_values_a_b2[j, i] = -np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([x, x]), np.array([b1_fixed,y])))

# %%
# Find the minimum value of the log likelihood function
min2 = np.min(z2_values_a_b2)
min2_index = np.where(z2_values_a_b2 == min2)
a_min_param2 = a_array2[min2_index[1][0]]
b2_min_param2 = b2_array2[min2_index[0][0]]
a_min_param2, b2_min_param2, min_a_b2_value
# Out:
# (-0.5499999999999998, -1.19, 16.369564775645813)

# %% [markdown]
# # Fix a and plot in b1 and b2

# %%
# Choose 2 grades: B and BB
d_g2 = [d_g[2], d_g[3]]
n_g2 = [n_g[2], n_g[3]]

# %%
# Fix a and plot the likelihood function in b1 and b2

# let fixed a the average of the 2 MM a values
a_fixed = np.mean(a_mm[1] + a_mm[2])

b1_small = np.linspace(-3, -1, 21)
b2_small = np.linspace(-3, -1, 21)

z_values_b1_b2_small = np.zeros((len(b1_small), len(b2_small)))

for i, x in enumerate(b1_small):
    for j, y in enumerate(b2_small):
        z_values_b1_b2_small[i, j] = -np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([a_fixed, a_fixed]), np.array([x, y])))

plt.contourf(b1_small, b2_small, z_values_b1_b2_small, 20, cmap='RdGy')
plt.colorbar()
plt.xlabel("b2")
plt.ylabel("b1")
plt.title("Log likelihood for different b1 values")
plt.show()
# Out:
# C:\Users\kissp\AppData\Local\Temp\ipykernel_27040\1193942073.py:13: RuntimeWarning: divide by zero encountered in log
#   z_values_b1_b2_small[i, j] = -np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([a_fixed, a_fixed]), np.array([x, y])))

# %%
z_min1 = np.min(z_values_b1_b2_small)
z_min_index1 = np.where(z_values_b1_b2_small == z_min1)
print(z_min1, z_min_index1)
print(b1_small[z_min_index1[0][0]], b2_small[z_min_index1[1][0]])
# Out:
# 20.069559943154022 (array([6], dtype=int64), array([13], dtype=int64))
# -2.4 -1.7

# %%
-np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([a_fixed, a_fixed]), np.array([b1_small[z_min_index1[0][0]], b2_small[z_min_index1[1][0]]])))
# Out:
# 20.069559943154022

# %%
-np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([a_fixed, a_fixed]), np.array([b1_small[z_min_index1[0][0]+1], b2_small[z_min_index1[1][0]+1]])))
# Out:
# 20.083385063046208

# %%
# Fix a and plot the likelihood function in b1 and b2

# let fixed a the average of the 2 MM a values
a_fixed = np.mean(a_mm[1] + a_mm[2])

b1 = np.linspace(-5, 1, 61)
b2 = np.linspace(-5, 1, 61)

z_values_b1_b2 = np.zeros((len(b1), len(b2)))

for i, x in enumerate(b1):
    for j, y in enumerate(b2):
        z_values_b1_b2[i, j] = -np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([a_fixed, a_fixed]), np.array([x, y])))

plt.contourf(b1, b2, z_values_b1_b2, 20, cmap='RdGy')
plt.colorbar()
plt.xlabel("b1")
plt.ylabel("b2")
plt.title("Log likelihood for different b1 values")
plt.show()
# Out:
# C:\Users\kissp\AppData\Local\Temp\ipykernel_27040\3007274989.py:13: RuntimeWarning: divide by zero encountered in log
#   z_values_b1_b2[i, j] = -np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([a_fixed, a_fixed]), np.array([x, y])))

# %%
# find max value and its index
min_z_value_b1_b2 = np.min(z_values_b1_b2)
min_z_index_b1_b2 = np.where(z_values_b1_b2 == min_z_value_b1_b2)
min_z_value_b1_b2, min_z_index_b1_b2
# Out:
# (20.069559943154, (array([26], dtype=int64), array([33], dtype=int64)))

# %%
b1[min_z_index_b1_b2[0][0]], b2[min_z_index_b1_b2[1][0]]
# Out:
# (-2.4, -1.6999999999999997)

# %%
-np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([a_fixed, a_fixed]), np.array([b1[min_z_index_b1_b2[0][0]], b2[min_z_index_b1_b2[1][0]]])))
# Out:
# 20.069559943154

# %%
w_calc_func(a_fixed, b1[min_z_index_b1_b2[0][0]]), gamma_calc_func(a_fixed, b1[min_z_index_b1_b2[0][0]]), w_calc_func(a_fixed, b2[min_z_index_b1_b2[1][0]]), gamma_calc_func(a_fixed, b2[min_z_index_b1_b2[1][0]])
# Out:
# (0.5751880612220471,
#  -1.963250895517714,
#  0.5751880612220471,
#  -1.390636050991714)

# %%
# Fix a and plot the likelihood function in b1 and b2

# let fixed a the average of the 2 MM a values
a_fixed = np.mean(a_mm[1] + a_mm[2])

b1_prec = np.linspace(-3, -1, 101)
b2_prec = np.linspace(-3, -1, 101)

z_values_b1_b2_prec = np.zeros((len(b1_prec), len(b2_prec)))

for i, x in enumerate(b1_prec):
    for j, y in enumerate(b2_prec):
        z_values_b1_b2_prec[i, j] = -np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([a_fixed, a_fixed]), np.array([x, y])))

plt.contourf(b1_prec, b2_prec, z_values_b1_b2_prec, 20, cmap='RdGy')
plt.colorbar()
plt.xlabel("b2")
plt.ylabel("b1")
plt.title("Log likelihood for different b1 values")
plt.show()
# Out:
# C:\Users\kissp\AppData\Local\Temp\ipykernel_27040\2665345071.py:13: RuntimeWarning: divide by zero encountered in log
#   z_values_b1_b2_prec[i, j] = -np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([a_fixed, a_fixed]), np.array([x, y])))

# %%
# find max value and its index
min_z_value_b1_b2_prec = np.min(z_values_b1_b2_prec)
min_z_index_b1_b2_prec = np.where(z_values_b1_b2_prec == min_z_value_b1_b2_prec)
b1_prec[min_z_index_b1_b2_prec[0][0]], b2_prec[min_z_index_b1_b2_prec[1][0]]
# Out:
# (-2.38, -1.72)

# %%
b1_zoom = np.linspace(-2.5, -2.3, 21)
b2_zoom = np.linspace(-1.8, -1.6, 21)

z_values_zoom = np.zeros((len(b1_zoom), len(b2_zoom)))

for i, x in enumerate(b1_zoom):
    for j, y in enumerate(b2_zoom):
        z_values_zoom[i, j] = -np.log(calculate_variable_changed_likelihood_arr(d_g2, n_g2, p_g, norm.pdf, np.array([a_fixed, a_fixed]), np.array([x, y])))

plt.contourf(b1_zoom, b2_zoom, z_values_zoom, 20, cmap='RdGy')
plt.colorbar()
plt.xlabel("b2")
plt.ylabel("b1")
plt.title("Log likelihood for different b1 values")
plt.show()
