# %%
import pandas as pd

# %%
# Read in rating_changes.xlxs file from the data folder and create a dataframe
rating_changes = pd.read_excel('data/rating_changes.xlsx')
rating_changes
# Out:
#                                 Company Name        Date  \
# 0     Almaviva-The Italian Innovation Co SpA  03/20/2024
# 1     Almaviva-The Italian Innovation Co SpA  03/20/2024
# 2     Almaviva-The Italian Innovation Co SpA  03/20/2024
# 3                         CareTrust REIT Inc  03/20/2024
# 4                 GrafTech International Ltd  03/20/2024
# ...                                      ...         ...
# 4995        Taiping General Insurance Co Ltd  10/16/2023
# 4996              Taiping Reinsurance Co Ltd  10/16/2023
# 4997              Affiliated FM Insurance Co  10/13/2023
# 4998                            Alliander NV  10/13/2023
# 4999                            Alliander NV  10/13/2023
#
#                    Rating Type Agency Curr Rtg Last Rtg Ctry/Reg  \
# 0       LT Local Issuer Credit    S&P       BB      BB-       IT
# 1     LT Foreign Issuer Credit    S&P       BB      BB-       IT
# 2                      Outlook    S&P   STABLE      NaN       IT
# ...

# %%
rating_changes.shape
# Out:
# (5000, 9)

# %%
rating_changes[rating_changes['Curr Rtg'] == 'D']
# Out:
#                                            Company Name        Date  \
# 39                                    Jo-Ann Stores LLC  03/19/2024
# 40                                    Jo-Ann Stores LLC  03/19/2024
# 41                                            JOANN Inc  03/19/2024
# 42                                            JOANN Inc  03/19/2024
# 1262                              Hornblower HoldCo LLC  02/21/2024
# 1263                              Hornblower HoldCo LLC  02/21/2024
# 1278                                    Tribe Buyer LLC  02/21/2024
# 1279                                    Tribe Buyer LLC  02/21/2024
# 1343                                         Enviva Inc  02/16/2024
# 1344                                         Enviva Inc  02/16/2024
# 1351                                   Range Parent Inc  02/16/2024
# 1352                                   Range Parent Inc  02/16/2024
# 1621                                    Cano Health Inc  02/05/2024
# ...

# %%
len(set(rating_changes['Company Name']))
# Out:
# 1985
